# %%
import pandas as pd

def to_int(x):
    try:
        return int(x)
    except Exception:
        print(x)
        return 0

df = pd.read_csv('summarization.csv')\
    .dropna(subset=['Author Keywords'])

def norm(kw):
    kw = kw.strip()
    if len(kw) == 0:
        return None
    return kw

df['Author Keywords'] = df['Author Keywords'].apply(lambda x: [norm(kw) for kw in str(x).lower().split(';') if norm(kw) is not None])
df_cnt = df[['Year', 'Author Keywords']]\
    .rename(columns={'Author Keywords': 'Count'})\
    .groupby('Year')\
    .count()\
    .reset_index()
df_kw_by_year = df[['Year', 'Author Keywords', 'Titles']]\
    .rename(columns={'Titles': 'Count'})\
    .explode('Author Keywords')\
    .groupby(['Year', 'Author Keywords'])\
    .count()\
    .reset_index()
df_kw_by_year = df_kw_by_year.sort_values(['Year','Count'], ascending=False).groupby('Year').head(10)
df_kw_by_year['rank'] = 10 - df_kw_by_year.groupby('Year').cumcount()
# df_kw_by_year['Count'] = df_kw_by_year.apply(lambda x: to_int(x['Count']) / to_int(df_cnt[df_cnt['Year']==x['Year']]['Count'].values[0]), axis=1)

# %%
df_kw_by_year
# Out:
#        Year                                    Author Keywords  Count  rank
# 43376  2023                                 text summarization     13    10
# 43308  2023                        natural language processing      8     9
# 43153  2023                          abstractive summarization      6     8
# 43203  2023                                      deep learning      6     7
# 43231  2023                           extractive summarization      3     6
# ...     ...                                                ...    ...   ...
# 9      1974                                 statistical tables      1     5
# 0      1973            clinical psychology internship training      1    10
# 1      1973                              internship innovation      1     9
# 2      1973  lecture with discussion vs. role-playing vs. m...      1     8
# 3      1973  microcounseling training, interviewing skills,...      1     7
#
# [438 rows x 4 columns]

# %%
i = 0
for idx, v in df_kw_by_year.iterrows():
    if i % 10 == 0:
        print()
        print(v.Year)
#     print(f'{v.Year} {v.Count} {v["Author Keywords"]}')
#     print(str(v.Count * 100)[:5])
    print(v["Author Keywords"])
    i = i+1
# Out:
# 2023
# text summarization
# natural language processing
# abstractive summarization
# deep learning
# extractive summarization
# nlp
# summarization
# video summarization
# attention mechanism
# automatic text summarization
#
# 2022
# text summarization
# deep learning
# natural language processing
# video summarization
# summarization
# abstractive summarization
# machine learning
# extractive summarization
# automatic text summarization
# nlp
#
# 2021
# text summarization
# natural language processing
# summarization
# deep learning
# video summarization
# machine learning
# abstractive summarization
# extractive summarization
# bert
# nlp
#
# 2020
# text summarization
# natural language processing
# deep learning
# summarization
# video summarization
# machine learning
# extractive summarization
# abstractive summarization
# attention mechanism
# multi-document summarization
#
# 2019
# text summarization
# summarization
# video summarization
# natural language processing
# deep learning
# machine learning
# extractive summarization
# text mining
# clustering
# information retrieval
#
# 2018
# summarization
# text summarization
# natural language processing
# video summarization
# deep learning
# machine learning
# extractive summarization
# text mining
# automatic text summarization
# information retrieval
#
# 2017
# summarization
# video summarization
# text summarization
# text mining
# machine learning
# natural language processing
# sentiment analysis
# clustering
# data mining
# classification
#
# 2016
# summarization
# video summarization
# text summarization
# natural language processing
# clustering
# information retrieval
# multi-document summarization
# sentiment analysis
# machine learning
# information extraction
#
# 2015
# summarization
# video summarization
# text summarization
# clustering
# natural language processing
# sentiment analysis
# multi-document summarization
# opinion mining
# text mining
# data mining
#
# 2014
# summarization
# video summarization
# text summarization
# multi-document summarization
# natural language processing
# clustering
# opinion mining
# data mining
# sentiment analysis
# feature extraction
#
# 2013
# summarization
# video summarization
# text summarization
# natural language processing
# clustering
# automatic summarization
# multi-document summarization
# data mining
# machine learning
# text mining
#
# 2012
# summarization
# video summarization
# multi-document summarization
# text summarization
# natural language processing
# automatic summarization
# clustering
# information retrieval
# sentiment analysis
# text mining
#
# 2011
# summarization
# video summarization
# text summarization
# information retrieval
# clustering
# multi-document summarization
# text mining
# visualization
# automatic summarization
# document summarization
#
# 2010
# summarization
# video summarization
# text summarization
# multi-document summarization
# information retrieval
# information extraction
# natural language processing
# clustering
# data mining
# text mining
#
# 2009
# summarization
# text summarization
# video summarization
# automatic summarization
# clustering
# natural language processing
# text mining
# multi-document summarization
# document summarization
# automatic text summarization
#
# 2008
# summarization
# video summarization
# multi-document summarization
# information retrieval
# text summarization
# trecvid
# clustering
# data mining
# evaluation
# automatic summarization
#
# 2007
# summarization
# video summarization
# text summarization
# clustering
# evaluation
# automatic summarization
# text mining
# multi-document summarization
# trecvid
# information retrieval
#
# 2006
# summarization
# video summarization
# text summarization
# clustering
# information retrieval
# natural language processing
# text mining
# automatic text summarization
# data mining
# multi-document summarization
#
# 2005
# summarization
# video summarization
# text summarization
# automatic summarization
# multi-document summarization
# clustering
# data mining
# machine learning
# natural language processing
# text mining
#
# 2004
# summarization
# video summarization
# clustering
# mpeg-7
# automatic summarization
# text summarization
# information visualization
# metadata
# natural language processing
# video content analysis
#
# 2003
# video summarization
# summarization
# text summarization
# data mining
# natural language processing
# mpeg-7
# clustering
# hypervideo
# information extraction
# information retrieval
#
# 2002
# video summarization
# summarization
# information retrieval
# mpeg-7
# humans
# video indexing
# computer science
# event detection
# personalization
# recognition
#
# 2001
# summarization
# mpeg-7
# text summarization
# video summarization
# video indexing
# multimedia
# abstracts
# automatic dictionary creation
# clustering
# document summarization
#
# 2000
# information retrieval
# summarization
# video browsing
# video summarization
# image retrieval
# machine learning
# multimedia
# navigation
# query expansion
# software libraries
#
# 1999
# information retrieval
# adaptive spacecraft scheduling
# anomaly index
# approaching earthquake
# auditory
# barley (hordeum vulgare l.)
# bayesian prediction
# bean (phaseolus vulgaris l.)
# chemotherapy
# classifier
#
# 1998
# information retrieval
# video summarization
# accuracy assessment
# acid-resistant and heat-resistant mastic
# auditory localization
# automatic video annotation
# benefit/risk assessment
# biofacies
# calibration
# camera calibration
#
# 1997
# data mining
# artificial intelligence
# fuzzy set application
# summarization
# summary discovery
# video summarization
# abstracts
# activity models
# aggregation
# analysis
#
# 1996
# afterburner
# agriculture
# alginates
# automatic summarization
# awgn
# bmla/ls
# cells
# channel fading model
# china
# compliance
#
# 1995
# augmentative and alternative communication (aac)
# discourse comprehension
# speech synthesis
# aggregation
# aqueous solution
# automated abstracting
# automated summarization
# condensation
# corba
# databases
#
# 1994
# clinical trials
# adult periodontitis
# adults
# american dental association
# augmentative alternative communication (aac)
# blood se
# communication partners
# data interpretation
# discourse comprehension
# efficacy
#
# 1993
# computer simulation
# epidemiologic methods
# epidemiology
# gene expression
# health-care management
# health-care planning
# hybridization histochemistry
# man-machine interaction
# morphometry
# mrna
#
# 1992
# base variable
# bivariate maps
# breast cancer
# brushing
# cancer incidence
# cancer trends
# comparison plots
# compatibility
# comprehension monitoring
# effluents
#
# 1991
# 3-d display
# 3-d treatment planning
# acid rain
# cognitive modelling
# conducting airways
# cumulants
# database
# dosimetry
# fuzzy sets
# gradient
#
# 1990
# abstract interpretation
# committed-choice
# compilation
# concept development
# cox's proportional hazards regression model
# determinacy
# failure-time data
# logic program
# mode
# multiple regression analysis
#
# 1989
# ade regression
# asymptotic theory
# data compression
# fisher information
# glim models
# information geometry
# information loss
# kernel estimation
# multi-terminal information theory
# nonparametric estimation
#
# 1988
# artificial intelligence
# belief functions
# central otago
# clutha catchment
# community structure
# dempster-shafer
# depleted land
# environmental impact assessment
# evidential reasoning
# expert systems
#
# 1987
# automation
# birth rate
# c57bl/nnia mice
# coding
# concentration
# data management
# death rate
# digiscan
# habituation
# locomotor activity
#
# 1986
# image analysis
# image restoration
# intraclass correlation coefficient
# markov random field
# measurement variability
# nticonvulsants
# pattern recognition
# pharmacokinetics
# phenytoin suspension
# phenytoin‐bioavailability
#
# 1985
# charpy absorbed energy
# fracture toughness
# statistical analysis
# strength of materials
# tan h curve fit
# canister technique
# carcinogenesis
# central tendency
# descriptive statistics
# globodera pallida
#
# 1982
# globodera rostochiensis
# hand-held terminal
# micro-computer
# potato
# potato cyst nematode
# artificial intelligence
# computational linguistics
# computer graphics
# data analysis
# diagrams
#
# 1981
# fitting
# graphics languages
# high-level languages
# inference
# interactive computing
# classification
# clustering
# composite clustering
# data processing
# multivariate analysis
#
# 1980
# numerical classification
# outliers
# redundancy
# statistical vs traditional procedures, summarization of psychology research findings, college students & faculty
# mental patients
# mentally retarded
# observational assessment
# reliability
# analysis
# applied regression
#
# 1979
# clinical frequencies recording system (cfrs)
# cloud seeding
# covariance analysis
# data
# model based on microlevel & macrolevel description of semantic structure of texts, text comprehension & production of recall & summarization protocols
# histological and histochemical appraisal
# silvered sakiwinki
# skin of primates
# cross tabulation
# hierarchical data files
#
# 1974
# language
# nonprocedural
# problem oriented
# statistical tables
# clinical psychology internship training
# internship innovation
# lecture with discussion vs. role-playing vs. modeling training resident assistants in human relations skills, college student resident hall assistants
# microcounseling training, interviewing skills, medical students

# %% [markdown]
# До 2015 года было ключевое слово Impact Factor
# В 2021 году появилось ключевое слово vosviewer (Сама программа появилась в 2020 году)

# %%
df_kw_by_year['Author Keywords'].value_counts().head(10)
# Out:
# video summarization             26
# summarization                   25
# text summarization              22
# natural language processing     18
# clustering                      18
# information retrieval           14
# multi-document summarization    13
# text mining                     12
# data mining                     10
# machine learning                10
# Name: Author Keywords, dtype: int64
